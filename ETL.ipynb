# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Dataframe HECHOS

# %% [markdown]
# Se carga primero la pestaña de **HECHOS** del archivo homicidios.xlsx

# %%
df_hechos = pd.read_excel(r'Datasets/homicidios.xlsx', sheet_name='HECHOS')

# %%
df_hechos.head(1)
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...    NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
#
#                                XY (CABA)         pos x         pos y  \
# 0  Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
#
#   PARTICIPANTES VICTIMA ACUSADO
# 0     MOTO-AUTO    MOTO    AUTO
#
# [1 rows x 21 columns]

# %%
df_hechos.shape
# Out:
# (696, 21)

# %% [markdown]
# ## Dataframe VICTIMAS

# %% [markdown]
# Se carga la pestaña **VICTIMAS** del archivo homicidio.xlsx

# %%
df_victimas=pd.read_excel(r'Datasets/homicidios.xlsx', sheet_name='VICTIMAS')

# %%
df_victimas.head(1)
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00

# %%
df_victimas.shape
# Out:
# (717, 10)

# %% [markdown]
# ## Dataframe HOMICIDIOS

# %% [markdown]
# Vamos a unir los dos dataframes para poder ver y procesar mejor la información.

# %%
df_homicidios = pd.merge(df_hechos, df_victimas, left_on='ID', right_on='ID_hecho')

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     717 non-null    object
#  1   N_VICTIMAS             717 non-null    int64
#  2   FECHA_x                717 non-null    datetime64[ns]
#  3   AAAA_x                 717 non-null    int64
#  4   MM_x                   717 non-null    int64
#  5   DD_x                   717 non-null    int64
#  6   HORA                   717 non-null    object
#  7   HH                     717 non-null    object
#  8   LUGAR_DEL_HECHO        717 non-null    object
#  9   TIPO_DE_CALLE          717 non-null    object
#  10  Calle                  716 non-null    object
#  11  Altura                 133 non-null    float64
#  12  Cruce                  540 non-null    object
#  13  Dirección Normalizada  708 non-null    object
#  14  COMUNA                 717 non-null    int64
#  15  XY (CABA)              717 non-null    object
#  16  pos x                  717 non-null    object
#  17  pos y                  717 non-null    object
#  18  PARTICIPANTES          717 non-null    object
#  19  VICTIMA_x              717 non-null    object
#  20  ACUSADO                717 non-null    object
#  21  ID_hecho               717 non-null    object
#  22  FECHA_y                717 non-null    datetime64[ns]
#  23  AAAA_y                 717 non-null    int64
#  24  MM_y                   717 non-null    int64
#  25  DD_y                   717 non-null    int64
#  26  ROL                    717 non-null    object
#  27  VICTIMA_y              717 non-null    object
#  28  SEXO                   717 non-null    object
#  29  EDAD                   717 non-null    object
#  30  FECHA_FALLECIMIENTO    717 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(8), object(20)
# memory usage: 173.8+ KB

# %%
df_homicidios.head(1)
# Out:
#           ID  N_VICTIMAS    FECHA_x  AAAA_x  MM_x  DD_x      HORA HH  \
# 0  2016-0001           1 2016-01-01    2016     1     1  04:00:00  4
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...   ID_hecho  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...  2016-0001
#
#      FECHA_y AAAA_y MM_y  DD_y        ROL VICTIMA_y       SEXO EDAD  \
# 0 2016-01-01   2016    1     1  CONDUCTOR      MOTO  MASCULINO   19
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
#
# [1 rows x 31 columns]

# %%
df_homicidios.shape
# Out:
# (717, 31)

# %%
df_homicidios.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA_x', 'AAAA_x', 'MM_x', 'DD_x', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA_x', 'ACUSADO', 'ID_hecho', 'FECHA_y',
#        'AAAA_y', 'MM_y', 'DD_y', 'ROL', 'VICTIMA_y', 'SEXO', 'EDAD',
#        'FECHA_FALLECIMIENTO'],
#       dtype='object')

# %% [markdown]
# Se comienza eliminando la información que no se utilizará o es redundante.

# %%
df_homicidios.drop(['ID', 'HH','FECHA_y','AAAA_y', 'MM_y', 'DD_y','XY (CABA)','VICTIMA_y',
                    'FECHA_FALLECIMIENTO','AAAA_x','MM_x','DD_x','Calle','Altura','Cruce',
                    'Dirección Normalizada'],axis=1,inplace=True)

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   N_VICTIMAS       717 non-null    int64
#  1   FECHA_x          717 non-null    datetime64[ns]
#  2   HORA             717 non-null    object
#  3   LUGAR_DEL_HECHO  717 non-null    object
#  4   TIPO_DE_CALLE    717 non-null    object
#  5   COMUNA           717 non-null    int64
#  6   pos x            717 non-null    object
#  7   pos y            717 non-null    object
#  8   PARTICIPANTES    717 non-null    object
#  9   VICTIMA_x        717 non-null    object
#  10  ACUSADO          717 non-null    object
#  11  ID_hecho         717 non-null    object
#  12  ROL              717 non-null    object
#  13  SEXO             717 non-null    object
#  14  EDAD             717 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(12)
# memory usage: 84.2+ KB

# %% [markdown]
# Movemos la columna *ID_hecho* al principio de todo.

# %%
col = df_homicidios.pop('ID_hecho')
df_homicidios.insert(0, col.name, col)

# %% [markdown]
# Cambiamos los nombres de las columnas

# %%
df_homicidios.columns
# Out:
# Index(['ID_hecho', 'N_VICTIMAS', 'FECHA_x', 'HORA', 'LUGAR_DEL_HECHO',
#        'TIPO_DE_CALLE', 'COMUNA', 'pos x', 'pos y', 'PARTICIPANTES',
#        'VICTIMA_x', 'ACUSADO', 'ROL', 'SEXO', 'EDAD'],
#       dtype='object')

# %%
df_homicidios.rename(columns={'N_VICTIMAS':'cant_victimas','FECHA_x':'fecha', 'AAAA_x':'año', 
                              'MM_x':'mes', 'DD_x':'día', 'Dirección Normalizada':'dirección', 
                              'pos x':'longitud', 'pos y':'latitud','VICTIMA_x':'victima',
                              'PARTICIPANTES':'Involucrados'}, inplace=True)
df_homicidios.columns = df_homicidios.columns.str.lower()

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_hecho         717 non-null    object
#  1   cant_victimas    717 non-null    int64
#  2   fecha            717 non-null    datetime64[ns]
#  3   hora             717 non-null    object
#  4   lugar_del_hecho  717 non-null    object
#  5   tipo_de_calle    717 non-null    object
#  6   comuna           717 non-null    int64
#  7   longitud         717 non-null    object
#  8   latitud          717 non-null    object
#  9   involucrados     717 non-null    object
#  10  victima          717 non-null    object
#  11  acusado          717 non-null    object
#  12  rol              717 non-null    object
#  13  sexo             717 non-null    object
#  14  edad             717 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(12)
# memory usage: 84.2+ KB

# %% [markdown]
# Se da un primer vistazo a la cantidad de nulos.

# %%
df_homicidios.isnull().sum()
# Out:
# id_hecho           0
# cant_victimas      0
# fecha              0
# hora               0
# lugar_del_hecho    0
# tipo_de_calle      0
# comuna             0
# longitud           0
# latitud            0
# involucrados       0
# victima            0
# acusado            0
# rol                0
# sexo               0
# edad               0
# dtype: int64

# %%
df_homicidios.columns
# Out:
# Index(['id_hecho', 'cant_victimas', 'fecha', 'hora', 'lugar_del_hecho',
#        'tipo_de_calle', 'comuna', 'longitud', 'latitud', 'involucrados',
#        'victima', 'acusado', 'rol', 'sexo', 'edad'],
#       dtype='object')

# %% [markdown]
# ## Transformación de las columnas
# Se revisará cada columna para verificar la integridad mínima de los datosy así pasar a la postetiror etapa, en este caso el EDA.

# %% [markdown]
# ### is_hecho
#
# Se verifica que no haya duplicados

# %%
df_homicidios['id_hecho'].duplicated().sum()
# Out:
# 21

# %% [markdown]
# En este caso los duplicados se permiten ya que cada clave de identificación de hecho esta relacionada con las víctimas

# %%
df_homicidios[df_homicidios['id_hecho'].duplicated(keep=False)]
# Out:
#       id_hecho  cant_victimas      fecha      hora  \
# 29   2016-0041              2 2016-03-29  11:00:00
# 30   2016-0041              2 2016-03-29  11:00:00
# 98   2016-0126              2 2016-09-18  22:45:00
# 99   2016-0126              2 2016-09-18  22:45:00
# 163  2017-0026              2 2017-02-26  05:15:00
# 164  2017-0026              2 2017-02-26  05:15:00
# 173  2017-0035              3 2017-03-23  05:00:00
# 174  2017-0035              3 2017-03-23  05:00:00
# 175  2017-0035              3 2017-03-23  05:00:00
# 176  2017-0036              2 2017-03-29  18:00:00
# 177  2017-0036              2 2017-03-29  18:00:00
# 186  2017-0050              2 2017-04-28  11:08:08
# 187  2017-0050              2 2017-04-28  11:08:08
# 237  2017-0108              2 2017-09-02  04:53:08
# 238  2017-0108              2 2017-09-02  04:53:08
# 242  2017-0112              2 2017-09-10  09:32:17
# 243  2017-0112              2 2017-09-10  09:32:17
# 253  2017-0126              2 2017-10-14  06:15:00
# 254  2017-0126              2 2017-10-14  06:15:00
# 277  2017-0153              2 2017-12-11  02:00:00
# 278  2017-0153              2 2017-12-11  02:00:00
# 300  2018-0015              2 2018-02-06  01:00:00
# 301  2018-0015              2 2018-02-06  01:00:00
# 312  2018-0026              2 2018-03-09  04:45:00
# 313  2018-0026              2 2018-03-09  04:45:00
# 325  2018-0038              2 2018-04-20  17:10:00
# 326  2018-0038              2 2018-04-20  17:10:00
# 373  2018-0085              2 2018-08-03  18:16:00
# 374  2018-0085              2 2018-08-03  18:16:00
# 387  2018-0098              2 2018-09-09  05:00:00
# 388  2018-0098              2 2018-09-09  05:00:00
# 418  2018-0128              2 2018-11-25  04:30:00
# 419  2018-0128              2 2018-11-25  04:30:00
# 444  2019-0010              2 2019-02-02  07:50:00
# 445  2019-0010              2 2019-02-02  07:50:00
# 576  2020-0038              2 2020-08-30  04:00:00
# 577  2020-0038              2 2020-08-30  04:00:00
# 602  2020-0063              2 2020-12-05  07:10:00
# 603  2020-0063              2 2020-12-05  07:10:00
# 616  2020-0077              2 2020-12-25  06:40:00
# 617  2020-0077              2 2020-12-25  06:40:00
#
#                                        lugar_del_hecho tipo_de_calle  comuna  \
# 29                      AV DIRECTORIO Y RIVERA INDARTE       AVENIDA       7
# 30                      AV DIRECTORIO Y RIVERA INDARTE       AVENIDA       7
# 98                                IRIGOYEN Y TINOGASTA         CALLE      10
# 99                                IRIGOYEN Y TINOGASTA         CALLE      10
# 163                       AV. PERITO MORENO Y FOURNIER       AVENIDA       4
# 164                       AV. PERITO MORENO Y FOURNIER       AVENIDA       4
# 173  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA       1
# 174  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA       1
# 175  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA       1
# 176                CURUPAYTI Y COLECTORA AV. GRAL. PAZ      GRAL PAZ      12
# 177                CURUPAYTI Y COLECTORA AV. GRAL. PAZ      GRAL PAZ      12
# 186            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA       9
# 187            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA       9
# 237                            AV. GRAL. PAZ Y MACHAIN      GRAL PAZ      12
# 238                            AV. GRAL. PAZ Y MACHAIN      GRAL PAZ      12
# 242                         AU 25 DE MAYO Y AV. VARELA     AUTOPISTA       7
# 243                         AU 25 DE MAYO Y AV. VARELA     AUTOPISTA       7
# 253                      AV. RIESTRA Y CAÑADA DE GOMEZ       AVENIDA       8
# 254                      AV. RIESTRA Y CAÑADA DE GOMEZ       AVENIDA       8
# 277                             ROSARIO Y AV. LA PLATA       AVENIDA       6
# 278                             ROSARIO Y AV. LA PLATA       AVENIDA       6
# 300                                 Australia Av. 2800       AVENIDA       4
# 301                                 Australia Av. 2800       AVENIDA       4
# 312     Rabanal, Francisco, Intendente Av. y Saenz Av.       AVENIDA       4
# 313     Rabanal, Francisco, Intendente Av. y Saenz Av.       AVENIDA       4
# 325                                 AV. RIVADAVIA 1571       AVENIDA       1
# 326                                 AV. RIVADAVIA 1571       AVENIDA       1
# 373                Entre Rios Av. y Garay, Juan De Av.       AVENIDA       3
# 374                Entre Rios Av. y Garay, Juan De Av.       AVENIDA       3
# 387          Av. Gral. Paz e/ Ferre y Beron de Astrada      GRAL PAZ       8
# 388          Av. Gral. Paz e/ Ferre y Beron de Astrada      GRAL PAZ       8
# 418                               Paz, Gral. Av. 11200      GRAL PAZ       9
# 419                               Paz, Gral. Av. 11200      GRAL PAZ       9
# 444                            DEL LIBERTADOR AV. 4100       AVENIDA      14
# 445                            DEL LIBERTADOR AV. 4100       AVENIDA      14
# 576            LAS HERAS GENERAL AV. Y DIAZ, CNEL. AV.       AVENIDA      14
# 577            LAS HERAS GENERAL AV. Y DIAZ, CNEL. AV.       AVENIDA      14
# 602                           NUEVA YORK Y ALTA GRACIA         CALLE      11
# 603                           NUEVA YORK Y ALTA GRACIA         CALLE      11
# 616                      SAN MARTIN AV. Y PUNTA ARENAS       AVENIDA      15
# 617                      SAN MARTIN AV. Y PUNTA ARENAS       AVENIDA      15
#
#          longitud       latitud      involucrados      victima      acusado  \
# 29   -58.46076550  -34.63350444       MOTO-CARGAS         MOTO       CARGAS
# 30   -58.46076550  -34.63350444       MOTO-CARGAS         MOTO       CARGAS
# 98   -58.52572109  -34.62125906       AUTO-CARGAS         AUTO       CARGAS
# 99   -58.52572109  -34.62125906       AUTO-CARGAS         AUTO       CARGAS
# 163  -58.41842777  -34.64979057  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 164  -58.41842777  -34.64979057  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 173  -58.35881506  -34.61113641  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 174  -58.35881506  -34.61113641  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 175  -58.35881506  -34.61113641  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 176  -58.51452347  -34.58159762    MOTO-PASAJEROS         MOTO    PASAJEROS
# 177  -58.51452347  -34.58159762    MOTO-PASAJEROS         MOTO    PASAJEROS
# 186             .             .       MOTO-CARGAS         MOTO       CARGAS
# 187             .             .       MOTO-CARGAS         MOTO       CARGAS
# 237  -58.49491054  -34.54795581  AUTO-OBJETO FIJO  OBJETO FIJO         AUTO
# 238  -58.49491054  -34.54795581  AUTO-OBJETO FIJO  OBJETO FIJO         AUTO
# 242  -58.45807401  -34.63997430  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 243  -58.45807401  -34.63997430  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 253  -58.48003734  -34.68148508  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 254  -58.48003734  -34.68148508  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 277  -58.42855267  -34.61829385    MOTO-PASAJEROS         MOTO    PASAJEROS
# 278  -58.42855267  -34.61829385    MOTO-PASAJEROS         MOTO    PASAJEROS
# 300  -58.38636298  -34.64684275    MOTO-PASAJEROS         MOTO    PASAJEROS
# 301  -58.38636298  -34.64684275    MOTO-PASAJEROS         MOTO    PASAJEROS
# 312  -58.41657793  -34.65476216      MOVIL-CARGAS        MOVIL       CARGAS
# 313  -58.41657793  -34.65476216      MOVIL-CARGAS        MOVIL       CARGAS
# 325  -58.38872177  -34.60885045       PEATON-AUTO       PEATON         AUTO
# 326  -58.38872177  -34.60885045       PEATON-AUTO       PEATON         AUTO
# 373  -58.39118948  -34.62704273    MOTO-PASAJEROS         MOTO    PASAJEROS
# 374  -58.39118948  -34.62704273    MOTO-PASAJEROS         MOTO    PASAJEROS
# 387  -58.47199387  -34.69640164         AUTO-AUTO         AUTO         AUTO
# 388  -58.47199387  -34.69640164         AUTO-AUTO         AUTO         AUTO
# 418  -58.52844623  -34.64592873    AUTO-PASAJEROS         AUTO    PASAJEROS
# 419  -58.52844623  -34.64592873    AUTO-PASAJEROS         AUTO    PASAJEROS
# 444  -58.42668489  -34.56961468       PEATON-AUTO       PEATON         AUTO
# 445  -58.42668489  -34.56961468       PEATON-AUTO       PEATON         AUTO
# 576  -58.40617526  -34.58345898         AUTO-AUTO         AUTO         AUTO
# 577  -58.40617526  -34.58345898         AUTO-AUTO         AUTO         AUTO
# 602  -58.52783814  -34.61047001  PEATON_MOTO-MOTO  PEATON_MOTO         MOTO
# 603  -58.52783814  -34.61047001  PEATON_MOTO-MOTO  PEATON_MOTO         MOTO
# 616  -58.47220945  -34.60111373         MOTO-AUTO         MOTO         AUTO
# 617  -58.47220945  -34.60111373         MOTO-AUTO         MOTO         AUTO
#
#                       rol       sexo edad
# 29              CONDUCTOR  MASCULINO   54
# 30   PASAJERO_ACOMPAÑANTE  MASCULINO   SD
# 98              CONDUCTOR  MASCULINO   37
# 99   PASAJERO_ACOMPAÑANTE  MASCULINO   60
# 163  PASAJERO_ACOMPAÑANTE   FEMENINO   23
# 164             CONDUCTOR  MASCULINO   19
# 173             CONDUCTOR  MASCULINO   28
# 174  PASAJERO_ACOMPAÑANTE  MASCULINO   32
# 175  PASAJERO_ACOMPAÑANTE  MASCULINO   30
# 176  PASAJERO_ACOMPAÑANTE   FEMENINO   SD
# 177             CONDUCTOR  MASCULINO   20
# 186             CONDUCTOR  MASCULINO   46
# 187  PASAJERO_ACOMPAÑANTE  MASCULINO   16
# 237  PASAJERO_ACOMPAÑANTE  MASCULINO   17
# 238  PASAJERO_ACOMPAÑANTE  MASCULINO   10
# 242  PASAJERO_ACOMPAÑANTE  MASCULINO    1
# 243  PASAJERO_ACOMPAÑANTE  MASCULINO   SD
# 253  PASAJERO_ACOMPAÑANTE  MASCULINO   39
# 254             CONDUCTOR  MASCULINO   36
# 277  PASAJERO_ACOMPAÑANTE  MASCULINO   SD
# 278             CONDUCTOR  MASCULINO   30
# 300             CONDUCTOR  MASCULINO   28
# 301  PASAJERO_ACOMPAÑANTE  MASCULINO   19
# 312             CONDUCTOR  MASCULINO   24
# 313  PASAJERO_ACOMPAÑANTE  MASCULINO   30
# 325                PEATON   FEMENINO   59
# 326                PEATON  MASCULINO   61
# 373  PASAJERO_ACOMPAÑANTE   FEMENINO   22
# 374             CONDUCTOR  MASCULINO   30
# 387             CONDUCTOR  MASCULINO   55
# 388  PASAJERO_ACOMPAÑANTE  MASCULINO   54
# 418  PASAJERO_ACOMPAÑANTE  MASCULINO   49
# 419  PASAJERO_ACOMPAÑANTE   FEMENINO   39
# 444                PEATON  MASCULINO   SD
# 445                PEATON  MASCULINO   59
# 576             CONDUCTOR  MASCULINO   46
# 577             CONDUCTOR  MASCULINO   64
# 602                PEATON  MASCULINO   38
# 603  PASAJERO_ACOMPAÑANTE  MASCULINO   21
# 616             CONDUCTOR   FEMENINO   30
# 617  PASAJERO_ACOMPAÑANTE   FEMENINO   24

# %% [markdown]
# ### Cant_Victimas

# %% [markdown]
# En esta columna no hay inconvenientes

# %%
df_homicidios['cant_victimas'].value_counts()
# Out:
# cant_victimas
# 1    676
# 2     38
# 3      3
# Name: count, dtype: int64

# %% [markdown]
# ### Fecha

# %% [markdown]
# Se revisan los valores nulos en la columna hora

# %%
df_homicidios['fecha'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Hora

# %% [markdown]
# Ahora se convierte toda la columna hora en tipo de dato datetime, que es mejor para el manejo de la hora al igual que las fechas.

# %%
df_homicidios['hora']= pd.to_datetime(df_homicidios['hora'], format='%H:%M:%S', errors='coerce')

# %%
df_homicidios[df_homicidios['hora'].isnull()]
# Out:
#       id_hecho  cant_victimas      fecha hora          lugar_del_hecho  \
# 536  2019-0103              1 2019-12-18  NaT  PAZ, GRAL. AV. Y GRIVEO
#
#     tipo_de_calle  comuna      longitud       latitud involucrados victima  \
# 536      GRAL PAZ      11  -58.52169422  -34.59471640    MOTO-MOTO    MOTO
#
#     acusado        rol       sexo edad
# 536    MOTO  CONDUCTOR  MASCULINO   24

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_hecho         717 non-null    object
#  1   cant_victimas    717 non-null    int64
#  2   fecha            717 non-null    datetime64[ns]
#  3   hora             716 non-null    datetime64[ns]
#  4   lugar_del_hecho  717 non-null    object
#  5   tipo_de_calle    717 non-null    object
#  6   comuna           717 non-null    int64
#  7   longitud         717 non-null    object
#  8   latitud          717 non-null    object
#  9   involucrados     717 non-null    object
#  10  victima          717 non-null    object
#  11  acusado          717 non-null    object
#  12  rol              717 non-null    object
#  13  sexo             717 non-null    object
#  14  edad             717 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(11)
# memory usage: 84.2+ KB

# %% [markdown]
# ### Lugar_Del_Hecho

# %%
df_homicidios['lugar_del_hecho'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Comuna

# %%
df_homicidios[df_homicidios['comuna']==0]
# Out:
#       id_hecho  cant_victimas      fecha                hora  \
# 121  2016-0151              1 2016-11-18 1900-01-01 20:35:00
# 141  2016-0174              1 2016-12-27 1900-01-01 00:00:00
#
#           lugar_del_hecho tipo_de_calle  comuna longitud latitud involucrados  \
# 121                    SD         CALLE       0        .       .    PEATON-SD
# 141  AUTOPISTA 25 DE MAYO     AUTOPISTA       0        .       .        SD-SD
#
#     victima acusado     rol sexo edad
# 121  PEATON      SD  PEATON   SD   SD
# 141      SD      SD      SD   SD   SD

# %% [markdown]
# Al ver que a esas filas le faltan datos en varios campos se decide borrar estas filas.

# %%
df_homicidios=df_homicidios[df_homicidios['comuna']!=0]

# %% [markdown]
# ### Latitud y Longitud

# %% [markdown]
# Se crea una función para transformar las columnas Latitud y Longitud en float y en el caso de no poder reemplaza el valor por NaN

# %%
valores=list()
def transformar_float(x):
    try:
        return float(x)
    except:
        valores.append(x)

# %%
df_homicidios['latitud'] = df_homicidios['latitud'].apply(transformar_float)

# %%
valores
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']

# %%
valores=list()
def transformar_float(x):
    try:
        return float(x)
    except:
        valores.append(x)

# %%
df_homicidios['longitud'] = df_homicidios['longitud'].apply(transformar_float)

# %%
valores
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']

# %% [markdown]
# Como se aprecia los valores que no se puediero convertir en *float* son puntos, por lo que se remplazaran por **None**

# %%
def reemplazar(x):
    try:
        return float(x)
    except:
        return None

# %%
df_homicidios['latitud'] = df_homicidios['latitud'].apply(reemplazar)
df_homicidios['longitud'] = df_homicidios['longitud'].apply(reemplazar)

# %%
df_homicidios.columns
# Out:
# Index(['id_hecho', 'cant_victimas', 'fecha', 'hora', 'lugar_del_hecho',
#        'tipo_de_calle', 'comuna', 'longitud', 'latitud', 'involucrados',
#        'victima', 'acusado', 'rol', 'sexo', 'edad'],
#       dtype='object')

# %% [markdown]
# ### Involucrados, vicitma, acusado

# %%
df_homicidios[df_homicidios['involucrados'].str.contains('SD', na=False)][['involucrados', 'victima', 'acusado']]
# Out:
#      involucrados    victima acusado
# 3         MOTO-SD       MOTO      SD
# 33        MOTO-SD       MOTO      SD
# 36          SD-SD         SD      SD
# 39        MOTO-SD       MOTO      SD
# 58        AUTO-SD       AUTO      SD
# 77          SD-SD         SD      SD
# 84      PEATON-SD     PEATON      SD
# 89      SD-CARGAS         SD  CARGAS
# 93          SD-SD         SD      SD
# 107     PEATON-SD     PEATON      SD
# 114       MOTO-SD       MOTO      SD
# 128       AUTO-SD       AUTO      SD
# 162       MOTO-SD       MOTO      SD
# 167       SD-AUTO         SD    AUTO
# 204       MOTO-SD       MOTO      SD
# 208         SD-SD         SD      SD
# 221       SD-AUTO         SD    AUTO
# 223       MOTO-SD       MOTO      SD
# 280       SD-MOTO         SD    MOTO
# 409     PEATON-SD     PEATON      SD
# 413       AUTO-SD       AUTO      SD
# 457       AUTO-SD       AUTO      SD
# 468       MOTO-SD       MOTO      SD
# 475       MOTO-SD       MOTO      SD
# 641  PASAJEROS-SD  PASAJEROS      SD

# %%
df_homicidios[df_homicidios['involucrados']!=df_homicidios['victima'] +'-'+df_homicidios['acusado']]['involucrados'].count()
# Out:
# 22

# %%
df_homicidios[df_homicidios['involucrados']!=df_homicidios['victima'] +'-'+df_homicidios['acusado']][['involucrados', 'victima', 'acusado']]
# Out:
#          involucrados      victima   acusado
# 32           MULTIPLE         MOTO  MULTIPLE
# 63         MOTO-MOVIL         MOTO      OTRO
# 145          MULTIPLE       PEATON  MULTIPLE
# 148          MULTIPLE       PEATON  MULTIPLE
# 155          MULTIPLE         MOTO  MULTIPLE
# 180          MULTIPLE         AUTO  MULTIPLE
# 232          MULTIPLE       PEATON  MULTIPLE
# 237  AUTO-OBJETO FIJO  OBJETO FIJO      AUTO
# 238  AUTO-OBJETO FIJO  OBJETO FIJO      AUTO
# 288          MULTIPLE       PEATON  MULTIPLE
# 289          MULTIPLE         MOTO  MULTIPLE
# 347        MOTO-MOVIL         MOTO      OTRO
# 369          MULTIPLE       PEATON  MULTIPLE
# 386        AUTO-MOVIL         AUTO      OTRO
# 391          MULTIPLE         AUTO  MULTIPLE
# 442          MULTIPLE         MOTO  MULTIPLE
# 462          MULTIPLE    BICICLETA  MULTIPLE
# 476          MULTIPLE         AUTO  MULTIPLE
# 531          MULTIPLE         MOTO  MULTIPLE
# 568          MULTIPLE         MOTO  MULTIPLE
# 664          MULTIPLE         MOTO  MULTIPLE
# 693          MULTIPLE         MOTO  MULTIPLE

# %% [markdown]
# En base a lo evidenciado en las columnas de *involucrados*, *victimas* y *acusado*. Lo mejor es borrar la columna *participantes*.

# %% [markdown]
# ### Rol

# %%
df_homicidios['rol'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Sexo

# %%
df_homicidios['sexo'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### EDAD

# %%
df_homicidios['edad'].isnull().sum()
# Out:
# 0

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 715 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_hecho         715 non-null    object
#  1   cant_victimas    715 non-null    int64
#  2   fecha            715 non-null    datetime64[ns]
#  3   hora             714 non-null    datetime64[ns]
#  4   lugar_del_hecho  715 non-null    object
#  5   tipo_de_calle    715 non-null    object
#  6   comuna           715 non-null    int64
#  7   longitud         704 non-null    float64
#  8   latitud          704 non-null    float64
#  9   involucrados     715 non-null    object
#  10  victima          715 non-null    object
#  11  acusado          715 non-null    object
#  12  rol              715 non-null    object
#  13  sexo             715 non-null    object
#  14  edad             715 non-null    object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(9)
# memory usage: 89.4+ KB

# %%
df_homicidios.to_excel('Datasets/data.xlsx', index=False)
